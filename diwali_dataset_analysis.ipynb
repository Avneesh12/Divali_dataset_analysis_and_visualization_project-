# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Avniiii\Data_Analytics_class\datasets\Python_Diwali_Sales_Analysis\a.csv",encoding='windows-1252')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df['Amount'].fillna(df['Amount'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.sample()
# Out:
#       User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 5342  1001335    Kushal  P00177842      F     36-45   36               1
#
#         State     Zone Occupation Product_Category  Orders  Amount
# 5342  Gujarat  Western       Govt  Sports Products       3  8417.0

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5219.569870
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8110.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# Age Groups
df['Age Group'].value_counts()
# Out:
# 26-35    4543
# 36-45    2286
# 18-25    1879
# 46-50     987
# 51-55     832
# 55+       428
# 0-17      296
# Name: Age Group, dtype: int64

# %%
# Gender Counts
df['Gender'].value_counts()
# Out:
# F    7842
# M    3409
# Name: Gender, dtype: int64

# %%
# No. of States
df['State'].value_counts()
# Out:
# Uttar Pradesh       1946
# Maharashtra         1526
# Karnataka           1305
# Delhi               1107
# Madhya Pradesh       923
# Andhra Pradesh       812
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              429
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: State, dtype: int64

# %%
# Marital Status Counts
df['Marital_Status'].value_counts()
# Out:
# 0    6522
# 1    4729
# Name: Marital_Status, dtype: int64

# %%
# Maximum Aee
df['Age'].max()
# Out:
# 92

# %%
# Min Age
df['Age'].min()
# Out:
# 12

# %%
# Mean of Age
df['Age'].mean()
# Out:
# 35.421207003821884

# %%
# Product Count
df['Product_Category'].nunique()
# Out:
# 18

# %%
# Maximum No. of Order
df['Orders'].max()
# Out:
# 4

# %%
# Maximum Amount Spent
df['Amount'].max()
# Out:
# 23952.0

# %%
df.loc[df['Amount'].max()==df['Amount'],['User_ID','Cust_name','Amount','Product_Category']]
# Out:
#    User_ID  Cust_name   Amount Product_Category
# 0  1002903  Sanskriti  23952.0             Auto

# %%
df['Zone'].value_counts()
# Out:
# Central     4296
# Southern    2695
# Western     1955
# Northern    1491
# Eastern      814
# Name: Zone, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Madhya Pradesh',
#        'Jharkhand', 'Kerala', 'Haryana', 'Bihar', 'Rajasthan',
#        'Uttarakhand', 'Telangana', 'Punjab'], dtype=object)

# %%
df['State'].replace(to_replace=['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
       'Gujarat', 'Himachal Pradesh', 'Delhi', 'Madhya Pradesh',
       'Jharkhand', 'Kerala', 'Haryana', 'Bihar', 'Rajasthan',
       'Uttarakhand', 'Telangana', 'Punjab'],value=['MH','AP','UP','KRT','GJ','HP','DL','MP','JH',
                                                    'KL','HR','BR','RJ','UK','TL','PB'],inplace=True)

# %%
sns.lineplot(x='Age',y='Amount',data=df,marker='o')
# Out:
# <Axes: xlabel='Age', ylabel='Amount'>

# %% [markdown]
# # Data Visualization

# %%
# Amount Spend City WIse
sns.barplot(x='State',y='Amount',data=df)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
# No. of Male and Female Customers Marital Status Wise
sns.countplot(x=df['Gender'],hue=df['Marital_Status'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# No. of Customers Age Group Wise
sns.countplot(x=df['Age Group'])
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
# Amount Spent Zone wise and Gender
sns.barplot(x='Zone',y='Amount',data=df,hue='Gender')
# Out:
# <Axes: xlabel='Zone', ylabel='Amount'>

# %%
# Amount spend Gender and Merital status Wise
sns.barplot(x='Marital_Status',y='Amount',data=df,hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
# Amount Spend according to Occupation
plt.figure(figsize=(16,9))

sns.barplot(x='Occupation',y='Amount',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
# Count of Product Catagory
plt.figure(figsize=(24,9))
sns.countplot(x=df['Product_Category'])
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
# Amount Spen range
sns.distplot(df['Amount'],color='y')
# Out:
# C:\Users\Avniiii\AppData\Local\Temp\ipykernel_15832\1254067051.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'],color='y')
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
sns.distplot(df['Age'],color='g')
# Out:
# C:\Users\Avniiii\AppData\Local\Temp\ipykernel_15832\2956360862.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],color='g')
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# No. of Orders
plt.pie(df['Orders'].value_counts(),explode=[0.04,0.04,0.04,0.04],labels=df['Orders'].unique(),autopct="%0.1f%%",shadow=True)

plt.plot()
# Out:
# []

# %%
# Customers Age Grups in Percentage
plt.pie(df['Age Group'].value_counts(),labels=df['Age Group'].unique(),autopct="%0.1f%%",shadow=True)

plt.plot()
# Out:
# []
